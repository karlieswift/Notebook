# %%
cs=[
#     '#FFC1C1',#粉红
    '#FFA500',#orange
    '#FF69B4',#hotpink
    '#FF00FF',
    '#9B30FF',
    '#00008B',
    '#90EE90',
    '#FF7F24',
    '#9400D3',
    '#FFFF00',
    '#836FFF',
    '#A020F0',
    '#FFDAB9'
    
    
]

# %%
# import pandas as pd  
# df=pd.read_csv('./files/lanuge.csv')
# df=df.set_index('dates',drop=True)

# %%
import pandas as pd  
import bar_chart_race as bcr
# plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
# plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
df=pd.read_csv('./files/lanuge.csv')
df=df.set_index('dates',drop=True)
bcr.bar_chart_race(df=df, filename=None,n_bars=8,title='编程语言排行榜'
                  ,shared_fontdict={'sans-serif':'SimHei'},
                   cmap=cs
                  )
# Out:
# <video width="982" height="502" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
import pandas as pd  
import bar_chart_race as bcr
# plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
# plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
df=pd.read_excel('./files/能源.xlsx')
df=df.set_index('date',drop=True)
bcr.bar_chart_race(df=df, filename=None,n_bars=8,title='能源统计表'
                  ,shared_fontdict={'sans-serif':'SimHei'},
                   cmap= ['IndianRed', 'SandyBrown', 'MediumVioletRed', 'Gold', 'LightSeaGreen', 
              'DeepSkyBlue', 'SlateBlue', 'LightPink', 'BurlyWood', 'MediumSeaGreen']
                  )
# Out:
# C:\Users\karlieswift\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\karlieswift\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\karlieswift\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\karlieswift\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\karlieswift\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
import pandas as pd  
import bar_chart_race as bcr
# plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
# plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
df=pd.read_excel('./files/能源.xlsx')
df=df.set_index('date',drop=True)
bcr.bar_chart_race(df=df, filename=None,n_bars=8,title='能源统计表'
                  ,shared_fontdict={'sans-serif':'SimHei'},
                   cmap='dark12_r'
                  )
# Out:
# C:\Users\karlieswift\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\karlieswift\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\karlieswift\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\karlieswift\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\karlieswift\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
import bar_chart_race as bcr
# df = bcr.load_dataset('covid19_tutorial')
bcr.bar_chart_race(
        df=data, 
        filename=None, 
        orientation='h', 
        sort='desc', 
        n_bars=8, 
        fixed_order=False, 
        fixed_max=True, 
        steps_per_period=20, 
        period_length=500, 
        end_period_pause=0,
        interpolate_period=False, 
        period_label={'x': .98, 'y': .3, 'ha': 'right', 'va': 'center'}, 
        period_template='%B %d, %Y', 
        period_summary_func=lambda v, r: {'x': .98, 'y': .2, 
                                          's': f'Total deaths: {v.sum():,.0f}', 
                                          'ha': 'right', 'size': 11}, 
        perpendicular_bar_func='median', 
        cmap='dark12', 
        title='COVID-19 Deaths by Country', 
        bar_size=.95, 
        bar_textposition='inside',
        bar_texttemplate='{x:,.0f}', 
        bar_label_font=7, 
        tick_label_font=7, 
        tick_template='{x:,.0f}',
        shared_fontdict=None, 
        scale='linear', 
        fig=None, 
        writer=None, 
        bar_kwargs={'alpha': .7},
        fig_kwargs={'figsize': (6, 3.5), 'dpi': 144},
        filter_column_colors=False)

# %%
import pandas as pd

# %%
#所以的颜色

fr = open("./color.json",'r+')
dic = eval(fr.read())   #读取的str转换为字典
print(dic)
fr.close()
# Out:
# {'dark12': ['#2E91E5', '#1CA71C', '#DA16FF', '#B68100', '#EB663B', '#00A08B', '#FC0080', '#6C7C32', '#862A16', '#620042', '#DA60CA', '#0D2A63'], 'dark12_r': ['#0D2A63', '#DA60CA', '#620042', '#862A16', '#6C7C32', '#FC0080', '#00A08B', '#EB663B', '#B68100', '#DA16FF', '#1CA71C', '#2E91E5'], 'plotly3': ['#0508b8', '#1910d8', '#3c19f0', '#6b1cfb', '#981cfd', '#bf1cfd', '#dd2bfd', '#f246fe', '#fc67fd', '#fe88fc', '#fea5fd', '#febefe', '#fec3fe'], 'viridis': ['#440154', '#440256', '#450457', '#450559', '#46075a', '#46085c', '#460a5d', '#460b5e', '#470d60', '#470e61', '#471063', '#471164', '#471365', '#481467', '#481668', '#481769', '#48186a', '#481a6c', '#481b6d', '#481c6e', '#481d6f', '#481f70', '#482071', '#482173', '#482374', '#482475', '#482576', '#482677', '#482878', '#482979', '#472a7a', '#472c7a', '#472d7b', '#472e7c', '#472f7d', '#46307e', '#46327e', '#46337f', '#463480', '#453581', '#453781', '#453882', '#443983', '#443a83', '#443b84', '#433d84', '#433e85', '#423f85', '#424086', 
# ...

# %%
colors=[]
for c in dic:
    colors.append(c)
    print(c )
# Out:
# dark12
# dark12_r
# plotly3
# viridis
# cividis
# inferno
# magma
# plasma
# blackbody
# bluered
# electric
# hot
# jet
# rainbow
# blues
# bugn
# bupu
# gnbu
# greens
# greys
# orrd
# oranges
# pubu
# pubugn
# purd
# purples
# rdbu
# rdpu
# reds
# ylgn
# ylgnbu
# ylorbr
# ylorrd
# turbid
# thermal
# haline
# solar
# ice
# gray
# deep
# dense
# algae
# matter
# speed
# amp
# tempo
# burg
# burgyl
# redor
# oryel
# peach
# pinkyl
# mint
# blugrn
# darkmint
# emrld
# aggrnyl
# bluyl
# teal
# tealgrn
# purp
# purpor
# sunset
# magenta
# sunsetdark
# agsunset
# brwnyl
# _cols
# plotly3_r
# viridis_r
# cividis_r
# inferno_r
# magma_r
# plasma_r
# blackbody_r
# bluered_r
# electric_r
# hot_r
# jet_r
# rainbow_r
# blues_r
# bugn_r
# bupu_r
# gnbu_r
# greens_r
# greys_r
# orrd_r
# oranges_r
# pubu_r
# pubugn_r
# purd_r
# purples_r
# rdbu_r
# rdpu_r
# reds_r
# ylgn_r
# ylgnbu_r
# ylorbr_r
# ylorrd_r
# turbid_r
# thermal_r
# haline_r
# solar_r
# ice_r
# gray_r
# deep_r
# dense_r
# algae_r
# ...

# %%
pd.DataFrame
# Out:
#                       0
# 0                dark12
# 1              dark12_r
# 2               plotly3
# 3               viridis
# 4               cividis
# ..                  ...
# 294             tab20_r
# 295            tab20b_r
# 296            tab20c_r
# 297    twilight_shifted
# 298  twilight_shifted_r
#
# [299 rows x 1 columns]
